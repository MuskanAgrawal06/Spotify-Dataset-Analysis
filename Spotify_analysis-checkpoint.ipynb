# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df= pd.read_csv('Most Streamed Spotify Songs 2024.csv',encoding= 'unicode_escape')

# %%
df.shape #gives no. of roe=ws and column
# Out:
# (4600, 29)

# %%
df.head(5) #filter out first 5 values
# Out:
#                         Track                    Album Name          Artist  \
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single   Tommy Richman
# 1                 Not Like Us                   Not Like Us  Kendrick Lamar
# 2  i like the way you kiss me    I like the way you kiss me         Artemas
# 3                     Flowers              Flowers - Single     Miley Cyrus
# 4                     Houdini                       Houdini          Eminem
#
#   Release Date          ISRC All Time Rank  Track Score Spotify Streams  \
# 0    4/26/2024  QM24S2402528             1        725.4     390,470,936
# 1     5/4/2024  USUG12400910             2        545.9     323,703,884
# 2    3/19/2024  QZJ842400387             3        538.4     601,309,283
# 3    1/12/2023  USSM12209777             4        444.9   2,031,280,633
# 4    5/31/2024  USUG12403398             5        423.3     107,034,922
#
#   Spotify Playlist Count Spotify Playlist Reach  ...  SiriusXM Spins  \
# ...

# %%
df.info() #gives info about the column data type and which column have null vales
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Track                       4600 non-null   object
#  1   Album Name                  4600 non-null   object
#  2   Artist                      4595 non-null   object
#  3   Release Date                4600 non-null   object
#  4   ISRC                        4600 non-null   object
#  5   All Time Rank               4600 non-null   object
#  6   Track Score                 4600 non-null   float64
#  7   Spotify Streams             4487 non-null   object
#  8   Spotify Playlist Count      4530 non-null   object
#  9   Spotify Playlist Reach      4528 non-null   object
#  10  Spotify Popularity          3796 non-null   float64
#  11  YouTube Views               4292 non-null   object
#  12  YouTube Likes               4285 non-null   object
# ...

# %%
#drop blank columns having 0 non-null values
df.drop(['TIDAL Popularity'], axis=1, inplace= True)

# %%
df.shape
# Out:
# (4600, 28)

# %%
pd.isnull(df).sum() #gives total no. of null rows of each column
# Out:
# Track                            0
# Album Name                       0
# Artist                           5
# Release Date                     0
# ISRC                             0
# All Time Rank                    0
# Track Score                      0
# Spotify Streams                113
# Spotify Playlist Count          70
# Spotify Playlist Reach          72
# Spotify Popularity             804
# YouTube Views                  308
# YouTube Likes                  315
# TikTok Posts                  1173
# TikTok Likes                   980
# TikTok Views                   981
# YouTube Playlist Reach        1009
# Apple Music Playlist Count     561
# AirPlay Spins                  498
# SiriusXM Spins                2123
# Deezer Playlist Count          921
# Deezer Playlist Reach          928
# Amazon Playlist Count         1055
# Pandora Streams               1106
# Pandora Track Stations        1268
# Soundcloud Streams            3333
# Shazam Counts                  577
# ...

# %%
#delete null values 
df.dropna(inplace = True) #inplace make changes permanently

# %%
df.shape
# Out:
# (565, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 565 entries, 0 to 4590
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Track                       565 non-null    object
#  1   Album Name                  565 non-null    object
#  2   Artist                      565 non-null    object
#  3   Release Date                565 non-null    object
#  4   ISRC                        565 non-null    object
#  5   All Time Rank               565 non-null    object
#  6   Track Score                 565 non-null    float64
#  7   Spotify Streams             565 non-null    object
#  8   Spotify Playlist Count      565 non-null    object
#  9   Spotify Playlist Reach      565 non-null    object
#  10  Spotify Popularity          565 non-null    float64
#  11  YouTube Views               565 non-null    object
#  12  YouTube Likes               565 non-null    object
# ...

# %%
#data analysis
df.columns
# Out:
# Index(['Track', 'Album Name', 'Artist', 'Release Date', 'ISRC',
#        'All Time Rank', 'Track Score', 'Spotify Streams',
#        'Spotify Playlist Count', 'Spotify Playlist Reach',
#        'Spotify Popularity', 'YouTube Views', 'YouTube Likes', 'TikTok Posts',
#        'TikTok Likes', 'TikTok Views', 'YouTube Playlist Reach',
#        'Apple Music Playlist Count', 'AirPlay Spins', 'SiriusXM Spins',
#        'Deezer Playlist Count', 'Deezer Playlist Reach',
#        'Amazon Playlist Count', 'Pandora Streams', 'Pandora Track Stations',
#        'Soundcloud Streams', 'Shazam Counts', 'Explicit Track'],
#       dtype='object')

# %%
#analyising the int type data
df.describe()
# Out:
#        Track Score  Spotify Popularity  Apple Music Playlist Count  \
# count   565.000000          565.000000                  565.000000
# mean     61.544425           69.722124                   89.886726
# std      65.000014           11.175532                   85.325438
# min      19.500000            6.000000                    3.000000
# 25%      28.100000           65.000000                   32.000000
# 50%      40.700000           71.000000                   63.000000
# 75%      69.700000           76.000000                  122.000000
# max     725.400000           95.000000                  859.000000
#
#        Deezer Playlist Count  Amazon Playlist Count  Explicit Track
# count             565.000000             565.000000      565.000000
# mean               42.557522              35.398230        0.405310
# std                59.133480              32.222118        0.491387
# min                 1.000000               1.000000        0.000000
# ...

# %%
df[['Track Score' ,'Spotify Popularity' ,'Apple Music Playlist Count']].describe()
# Out:
#        Track Score  Spotify Popularity  Apple Music Playlist Count
# count   565.000000          565.000000                  565.000000
# mean     61.544425           69.722124                   89.886726
# std      65.000014           11.175532                   85.325438
# min      19.500000            6.000000                    3.000000
# 25%      28.100000           65.000000                   32.000000
# 50%      40.700000           71.000000                   63.000000
# 75%      69.700000           76.000000                  122.000000
# max     725.400000           95.000000                  859.000000

# %%
select_column= df.sort_values(by= 'Track Score', ascending= False)
selected_column =select_column[['Track', 'Track Score']].head(10)
print(selected_column) #filtering out the top 10 tracks on the basis of their track score
# Out:
#                             Track  Track Score
# 0             MILLION DOLLAR BABY        725.4
# 1                     Not Like Us        545.9
# 2      i like the way you kiss me        538.4
# 5                     Lovin On Me        410.1
# 9      BAND4BAND (feat. Lil Baby)        330.6
# 12                          LUNCH        316.3
# 15                           LALA        299.9
# 16  Fortnight (feat. Post Malone)        297.6
# 18                           BLUE        292.6
# 21                       Espresso        281.5

# %%
plt.figure(figsize=(25,10))
bar_width=1
plt.bar(selected_column['Track'],selected_column['Track Score'])
plt.xlabel('Track Name')
plt.ylabel('Track Score')
plt.tight_layout()
plt.show() #visualizing the track and track score

# %%
#comparison between spotify playlist count and azamzon playlist count
sorted= df.sort_values(by='Spotify Playlist Count',ascending= False)
plt.figure(figsize=(50,20))
bar_width=2
positions=np.arange(len(sorted))

spotify_bars=plt.bar(sorted['Track'],sorted['Spotify Playlist Count'],label= 'Spotify', color='blue')

apple_bars=plt.bar(sorted['Track'],sorted['Apple Music Playlist Count'],label= 'apple', color='coral')
plt.legend()
plt.show()

# %%
# Out:
# float64

# %%
spotifyname= df.nlargest(10,'Spotify Popularity')
print(spotifyname)
plt.figure(figsize=(8, 8))
plt.pie(spotifyname['Spotify Popularity'],labels=spotifyname['Track'], autopct='%1.1f%%')
plt.title('Top 5 Genres on Spotify')
plt.show()
# Out:
#                                     Track                    Album Name  \
# 36                     A Bar Song (Tipsy)            A Bar Song (Tipsy)
# 21                               Espresso                      Espresso
# 0                     MILLION DOLLAR BABY  Million Dollar Baby - Single
# 1                             Not Like Us                   Not Like Us
# 2              i like the way you kiss me    I like the way you kiss me
# 7                               Gata Only                     Gata Only
# 12                                  LUNCH          HIT ME HARD AND SOFT
# 40                     BIRDS OF A FEATHER          HIT ME HARD AND SOFT
# 10  I Had Some Help (feat. Morgan Wallen)               I Had Some Help
# 78                                CHIHIRO          HIT ME HARD AND SOFT
#
#                Artist Release Date          ISRC All Time Rank  Track Score  \
# 36          Shaboozey   04-12-2024  USUYG1541249            37        226.4
# ...

# %%
# Get the top 10 tracks by Spotify popularity
df= pd.read_csv('Most Streamed Spotify Songs 2024.csv',encoding= 'unicode_escape')
top_tracks = df.nlargest(10,'Apple Music Playlist Count')


# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_tracks['Apple Music Playlist Count'], labels=top_tracks['Track'], autopct='%1.1f%%')
plt.title('Top 10 Tracks on Spotify by Popularity')
plt.show()
